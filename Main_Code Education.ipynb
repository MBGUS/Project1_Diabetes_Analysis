# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
import seaborn as sns

# %% [markdown]
# # Getting the Data

# %%
# Codes for each Data Frame

diabetes_csv = "Data/National_Data.csv"
diabetes_df = pd.read_csv(diabetes_csv)
diabetes_df
# Out:
#        yearid  fipscode  raceid  ageid  genderid  educationid  indicatorid  \
# 0        1980        -1       0      5         0            0            1
# 1        1980        -1       0      5         0            0            1
# 2        1980        -1       0      6         0            0            1
# 3        1980        -1       0      6         0            0            1
# 4        1980        -1       0      6         0            0            1
# ...       ...       ...     ...    ...       ...          ...          ...
# 29097    2017        -1       1    100         0            0            2
# 29098    2017        -1       2     99         0            0            2
# 29099    2017        -1       2    100         0            0            2
# 29100    2017        -1       7     99         0            0            2
# 29101    2017        -1       7    100         0            0            2
#
#        miscid  datasourceid  estimateid  SuppressID  datasetid  GeoLevel  \
# 0           0            30          61           0         40  National
# 1           0            30         101           0         40  National
# 2           0             3          61           0          3  National
# 3           0             3         101           0          3  National
# 4           0            30          61           0         40  National
# ...       ...           ...         ...         ...        ...       ...
# 29097       0             3          72           0         31  National
# 29098       0             3          72           0         31  National
# 29099       0             3          72           0         31  National
# 29100       0             3          72           0         31  National
# 29101       0             3          72           0         31  National
#
#       Estimate SeEstimate LowerLimit UpperLimit
# 0            1        0.1        0.9        1.2
# 1          915         76        764       1065
# 2          5.4        0.3        4.8          6
# 3         2337        143       2054       2621
# 4          5.4        0.3        4.8          6
# ...        ...        ...        ...        ...
# 29097      6.1        0.5        5.2        7.1
# 29098      8.7        1.2        6.6       11.5
# 29099      9.2        1.3          7       12.1
# 29100      9.7        1.6          7       13.4
# 29101     10.8        1.8        7.8         15
#
# [29102 rows x 17 columns]

# %%
# Education ID Value Counts

diabetes_df["educationid"].value_counts()
# Out:
# 0    26000
# 3     1034
# 2     1034
# 1     1034
# Name: educationid, dtype: int64

# %%
# Level 0 Education All

diabetes_df[diabetes_df["educationid"] == 0]
# Out:
#        yearid  fipscode  raceid  ageid  genderid  educationid  indicatorid  \
# 0        1980        -1       0      5         0            0            1
# 1        1980        -1       0      5         0            0            1
# 2        1980        -1       0      6         0            0            1
# 3        1980        -1       0      6         0            0            1
# 4        1980        -1       0      6         0            0            1
# ...       ...       ...     ...    ...       ...          ...          ...
# 29097    2017        -1       1    100         0            0            2
# 29098    2017        -1       2     99         0            0            2
# 29099    2017        -1       2    100         0            0            2
# 29100    2017        -1       7     99         0            0            2
# 29101    2017        -1       7    100         0            0            2
#
#        miscid  datasourceid  estimateid  SuppressID  datasetid  GeoLevel  \
# 0           0            30          61           0         40  National
# 1           0            30         101           0         40  National
# 2           0             3          61           0          3  National
# 3           0             3         101           0          3  National
# 4           0            30          61           0         40  National
# ...       ...           ...         ...         ...        ...       ...
# 29097       0             3          72           0         31  National
# 29098       0             3          72           0         31  National
# 29099       0             3          72           0         31  National
# 29100       0             3          72           0         31  National
# 29101       0             3          72           0         31  National
#
#       Estimate SeEstimate LowerLimit UpperLimit
# 0            1        0.1        0.9        1.2
# 1          915         76        764       1065
# 2          5.4        0.3        4.8          6
# 3         2337        143       2054       2621
# 4          5.4        0.3        4.8          6
# ...        ...        ...        ...        ...
# 29097      6.1        0.5        5.2        7.1
# 29098      8.7        1.2        6.6       11.5
# 29099      9.2        1.3          7       12.1
# 29100      9.7        1.6          7       13.4
# 29101     10.8        1.8        7.8         15
#
# [26000 rows x 17 columns]

# %%
# Level 1 Education < Highschool

diabetes_df[diabetes_df["educationid"] == 1]
# Out:
#        yearid  fipscode  raceid  ageid  genderid  educationid  indicatorid  \
# 20       1980        -1       0     99         0            1            1
# 21       1980        -1       0     99         0            1            1
# 36       1980        -1       0    100         0            1            1
# 87       1981        -1       0     99         0            1            1
# 88       1981        -1       0     99         0            1            1
# ...       ...       ...     ...    ...       ...          ...          ...
# 29047    2015        -1       0    100         0            1            2
# 29063    2016        -1       0     99         0            1            2
# 29069    2016        -1       0    100         0            1            2
# 29085    2017        -1       0     99         0            1            2
# 29091    2017        -1       0    100         0            1            2
#
#        miscid  datasourceid  estimateid  SuppressID  datasetid  GeoLevel  \
# 20          0            30          61           0         40  National
# 21          0            30         101           0         40  National
# 36          0            30          61           0         40  National
# 87          0            30          61           0         40  National
# 88          0            30         101           0         40  National
# ...       ...           ...         ...         ...        ...       ...
# 29047       0             3          72           0         31  National
# 29063       0             3          72           0         31  National
# 29069       0             3          72           0         31  National
# 29085       0             3          72           0         31  National
# 29091       0             3          72           0         31  National
#
#       Estimate SeEstimate LowerLimit UpperLimit
# 20         6.4        0.3        5.8          7
# 21        2918        177       2569       3267
# 36           5        0.2        4.5        5.5
# 87         6.4        0.3        5.8        7.1
# 88        2943        174       2601       3285
# ...        ...        ...        ...        ...
# 29047       11          1        9.1       13.3
# 29063     11.9        1.4        9.5       14.8
# 29069     11.5        1.3        9.1       14.4
# 29085     12.5        1.9        9.4       16.8
# 29091     12.2        1.8        9.1       16.4
#
# [1034 rows x 17 columns]

# %%
# Level 2 Education Highschool

diabetes_df[diabetes_df["educationid"] == 2]
# Out:
#        yearid  fipscode  raceid  ageid  genderid  educationid  indicatorid  \
# 22       1980        -1       0     99         0            2            1
# 23       1980        -1       0     99         0            2            1
# 37       1980        -1       0    100         0            2            1
# 89       1981        -1       0     99         0            2            1
# 90       1981        -1       0     99         0            2            1
# ...       ...       ...     ...    ...       ...          ...          ...
# 29048    2015        -1       0    100         0            2            2
# 29064    2016        -1       0     99         0            2            2
# 29070    2016        -1       0    100         0            2            2
# 29086    2017        -1       0     99         0            2            2
# 29092    2017        -1       0    100         0            2            2
#
#        miscid  datasourceid  estimateid  SuppressID  datasetid  GeoLevel  \
# 22          0            30          61           0         40  National
# 23          0            30         101           0         40  National
# 37          0            30          61           0         40  National
# 89          0            30          61           0         40  National
# 90          0            30         101           0         40  National
# ...       ...           ...         ...         ...        ...       ...
# 29048       0             3          72           0         31  National
# 29064       0             3          72           0         31  National
# 29070       0             3          72           0         31  National
# 29086       0             3          72           0         31  National
# 29092       0             3          72           0         31  National
#
#       Estimate SeEstimate LowerLimit UpperLimit
# 22         2.5        0.2        2.2        2.8
# 23        1462        116       1234       1691
# 37         2.9        0.2        2.5        3.3
# 89         2.6        0.2        2.3          3
# 90        1609        121       1370       1849
# ...        ...        ...        ...        ...
# 29048      7.8        0.7        6.5        9.3
# 29064      7.2        0.7        5.9        8.8
# 29070      6.8        0.7        5.6        8.2
# 29086      6.3        0.8        4.9          8
# 29092      5.9        0.7        4.6        7.5
#
# [1034 rows x 17 columns]

# %%
# Level 3 Education > Highschool

diabetes_df[diabetes_df["educationid"] == 3]
# Out:
#        yearid  fipscode  raceid  ageid  genderid  educationid  indicatorid  \
# 24       1980        -1       0     99         0            3            1
# 25       1980        -1       0     99         0            3            1
# 38       1980        -1       0    100         0            3            1
# 91       1981        -1       0     99         0            3            1
# 92       1981        -1       0     99         0            3            1
# ...       ...       ...     ...    ...       ...          ...          ...
# 29049    2015        -1       0    100         0            3            2
# 29065    2016        -1       0     99         0            3            2
# 29071    2016        -1       0    100         0            3            2
# 29087    2017        -1       0     99         0            3            2
# 29093    2017        -1       0    100         0            3            2
#
#        miscid  datasourceid  estimateid  SuppressID  datasetid  GeoLevel  \
# 24          0            30          61           0         40  National
# 25          0            30         101           0         40  National
# 38          0            30          61           0         40  National
# 91          0            30          61           0         40  National
# 92          0            30         101           0         40  National
# ...       ...           ...         ...         ...        ...       ...
# 29049       0             3          72           0         31  National
# 29065       0             3          72           0         31  National
# 29071       0             3          72           0         31  National
# 29087       0             3          72           0         31  National
# 29093       0             3          72           0         31  National
#
#       Estimate SeEstimate LowerLimit UpperLimit
# 24         2.1        0.2        1.8        2.5
# 25        1033        105        826       1240
# 38         2.9        0.3        2.4        3.5
# 91         1.7        0.1        1.5        2.1
# 92         920         88        747       1092
# ...        ...        ...        ...        ...
# 29049      5.4        0.3        4.8        6.1
# 29065      5.7        0.4          5        6.5
# 29071      5.6        0.4        4.9        6.3
# 29087        6        0.5        5.1        7.1
# 29093      5.8        0.5        4.9        6.9
#
# [1034 rows x 17 columns]

# %%
# Columns in the Dataframe

diabetes_df.columns
# Out:
# Index(['yearid', 'fipscode', 'raceid', 'ageid', 'genderid', 'educationid',
#        'indicatorid', 'miscid', 'datasourceid', 'estimateid', 'SuppressID',
#        'datasetid', 'GeoLevel', 'Estimate', 'SeEstimate', 'LowerLimit',
#        'UpperLimit'],
#       dtype='object')

# %%
# Reduct column numbers, leave only necessary for this study

diabetes_education_df = diabetes_df.loc[:,["indicatorid","ageid","estimateid",
                                        "datasetid","educationid","yearid","Estimate"]]

# %%
diabetes_education_df
# Out:
#        indicatorid  ageid  estimateid  datasetid  educationid  yearid Estimate
# 0                1      5          61         40            0    1980        1
# 1                1      5         101         40            0    1980      915
# 2                1      6          61          3            0    1980      5.4
# 3                1      6         101          3            0    1980     2337
# 4                1      6          61         40            0    1980      5.4
# ...            ...    ...         ...        ...          ...     ...      ...
# 29097            2    100          72         31            0    2017      6.1
# 29098            2     99          72         31            0    2017      8.7
# 29099            2    100          72         31            0    2017      9.2
# 29100            2     99          72         31            0    2017      9.7
# 29101            2    100          72         31            0    2017     10.8
#
# [29102 rows x 7 columns]

# %%
# Education DF. Rename the educationid indicator using cut/bins

# Create bins
bins = [0,1,2,3]

# Create labels
labels = ["< Highschool","Highschool","> Highschool"]

# %%
# Slice data and place it into bins
diabetes_education_df["Education"] = pd.cut(diabetes_df["educationid"], bins,
                                           labels=labels)

# %%
diabetes_education_df[diabetes_education_df["indicatorid"] == 1]
# Out:
#        indicatorid  ageid  estimateid  datasetid  educationid  yearid  \
# 0                1      5          61         40            0    1980
# 1                1      5         101         40            0    1980
# 2                1      6          61          3            0    1980
# 3                1      6         101          3            0    1980
# 4                1      6          61         40            0    1980
# ...            ...    ...         ...        ...          ...     ...
# 28261            1     99          61         40            0    2017
# 28262            1     99         101          3            0    2017
# 28263            1     99         101         40            0    2017
# 28264            1    100          61          3            0    2017
# 28265            1    100          61         40            0    2017
#
#       Estimate Education
# 0            1       NaN
# 1          915       NaN
# 2          5.4       NaN
# 3         2337       NaN
# 4          5.4       NaN
# ...        ...       ...
# 28261     10.4       NaN
# 28262     4118       NaN
# 28263     4087       NaN
# 28264      9.3       NaN
# 28265     12.5       NaN
#
# [2546 rows x 8 columns]

# %% [markdown]
# # Cleaning the Data

# %%
# New Dataframe Cleaned only with education levels

education_clean_df = diabetes_education_df.dropna()

# %%
education_clean_df.head()
# Out:
#     indicatorid  ageid  estimateid  datasetid  educationid  yearid Estimate  \
# 20            1     99          61         40            1    1980      6.4
# 21            1     99         101         40            1    1980     2918
# 22            1     99          61         40            2    1980      2.5
# 23            1     99         101         40            2    1980     1462
# 24            1     99          61         40            3    1980      2.1
#
#        Education
# 20  < Highschool
# 21  < Highschool
# 22    Highschool
# 23    Highschool
# 24  > Highschool

# %% [markdown]
# # Number in 1000s (estimateid = 101)

# %%
education_clean_df
# Out:
#        indicatorid  ageid  estimateid  datasetid  educationid  yearid  \
# 20               1     99          61         40            1    1980
# 21               1     99         101         40            1    1980
# 22               1     99          61         40            2    1980
# 23               1     99         101         40            2    1980
# 24               1     99          61         40            3    1980
# ...            ...    ...         ...        ...          ...     ...
# 29086            2     99          72         31            2    2017
# 29087            2     99          72         31            3    2017
# 29091            2    100          72         31            1    2017
# 29092            2    100          72         31            2    2017
# 29093            2    100          72         31            3    2017
#
#       Estimate     Education
# 20         6.4  < Highschool
# 21        2918  < Highschool
# 22         2.5    Highschool
# 23        1462    Highschool
# 24         2.1  > Highschool
# ...        ...           ...
# 29086      6.3    Highschool
# 29087        6  > Highschool
# 29091     12.2  < Highschool
# 29092      5.9    Highschool
# 29093      5.8  > Highschool
#
# [3102 rows x 8 columns]

# %%
education_cleaner_df = education_clean_df.loc[
    (education_clean_df["indicatorid"] == 1) &
    (education_clean_df["ageid"] == 99) &
    (education_clean_df["datasetid"] == 40) &
    (education_clean_df["estimateid"] == 101) &
    (education_clean_df["yearid"] >= 2000)
]

# %%
education_cleaner_df.head()
# Out:
#       indicatorid  ageid  estimateid  datasetid  educationid  yearid Estimate  \
# 1361            1     99         101         40            1    2000     3765
# 1363            1     99         101         40            2    2000     3688
# 1365            1     99         101         40            3    2000     4349
# 1428            1     99         101         40            1    2001     3920
# 1430            1     99         101         40            2    2001     4329
#
#          Education
# 1361  < Highschool
# 1363    Highschool
# 1365  > Highschool
# 1428  < Highschool
# 1430    Highschool

# %%
# Number of Results

education_cleaner_df.count()
# Out:
# indicatorid    54
# ageid          54
# estimateid     54
# datasetid      54
# educationid    54
# yearid         54
# Estimate       54
# Education      54
# dtype: int64

# %%
len(education_cleaner_df["educationid"])
# Out:
# 54

# %%
# Reset Index

education_cleaner_df = education_cleaner_df.reset_index(drop = True)

# %%
education_cleaner_df.head()
# Out:
#    indicatorid  ageid  estimateid  datasetid  educationid  yearid Estimate  \
# 0            1     99         101         40            1    2000     3765
# 1            1     99         101         40            2    2000     3688
# 2            1     99         101         40            3    2000     4349
# 3            1     99         101         40            1    2001     3920
# 4            1     99         101         40            2    2001     4329
#
#       Education
# 0  < Highschool
# 1    Highschool
# 2  > Highschool
# 3  < Highschool
# 4    Highschool

# %% [markdown]
# # Pivot Table 1000

# %%
# Use Pivot Table
pivot_education = education_cleaner_df.pivot_table(values=["Estimate"], index=["yearid"],
                                                  columns=["Education"],aggfunc=np.sum)

# %%
pivot_education
# Out:
#               Estimate
# Education < Highschool Highschool > Highschool
# yearid
# 2000              3765       3688         4349
# 2001              3920       4329         4614
# 2002              3708       4386         5062
# 2003              3678       4064         6027
# 2004              3945       4797         6213
# 2005              3991       5093         6942
# 2006              4206       5567         7171
# 2007              4466       5562         7043
# 2008              4583       6179         7745
# 2009              4847       6579         8924
# 2010              4860       6156         9840
# 2011              4880       6109         9453
# 2012              4557       6612        10051
# 2013              4587       6586        10902
# 2014              4788       6745        10119
# 2015              4578       6858        11605
# 2016              4665       6611        11698
# 2017              4485       6317        12105

# %%
# Create a Plot for the dataset

pivot_education_df = pivot_education.copy()

# %% [markdown]
# # Percentage (estimateid = 61)

# %%
education_clean_df.head()
# Out:
#     indicatorid  ageid  estimateid  datasetid  educationid  yearid Estimate  \
# 20            1     99          61         40            1    1980      6.4
# 21            1     99         101         40            1    1980     2918
# 22            1     99          61         40            2    1980      2.5
# 23            1     99         101         40            2    1980     1462
# 24            1     99          61         40            3    1980      2.1
#
#        Education
# 20  < Highschool
# 21  < Highschool
# 22    Highschool
# 23    Highschool
# 24  > Highschool

# %%
education_percentage_df = education_clean_df.loc[
    (education_clean_df["indicatorid"] == 1) &
    (education_clean_df["ageid"] == 99) &
    (education_clean_df["datasetid"] == 40) &
    (education_clean_df["estimateid"] == 61) &
    (education_clean_df["yearid"] >= 2000)
]

# %%
education_percentage_df.head()
# Out:
#       indicatorid  ageid  estimateid  datasetid  educationid  yearid Estimate  \
# 1360            1     99          61         40            1    2000     10.5
# 1362            1     99          61         40            2    2000        6
# 1364            1     99          61         40            3    2000      4.2
# 1427            1     99          61         40            1    2001     11.1
# 1429            1     99          61         40            2    2001      7.3
#
#          Education
# 1360  < Highschool
# 1362    Highschool
# 1364  > Highschool
# 1427  < Highschool
# 1429    Highschool

# %% [markdown]
# # Pivot Table Percentage

# %%
# Use Pivot Table
pivot_percentage_education = education_percentage_df.pivot_table(values=["Estimate"], index=["yearid"],
                                                  columns=["Education"],aggfunc=np.sum)

# %%
pivot_percentage_education
# Out:
#               Estimate
# Education < Highschool Highschool > Highschool
# yearid
# 2000              10.5          6          4.2
# 2001              11.1        7.3          4.3
# 2002                11        7.2          4.7
# 2003              10.4        6.6          5.4
# 2004              11.1        7.7          5.4
# 2005              11.4          8            6
# 2006              11.4        8.8          6.1
# 2007              12.9        8.7          5.8
# 2008              13.3         10          6.1
# 2009              14.5       10.5          6.9
# 2010              14.8         10          7.3
# 2011              14.8         10            7
# 2012              13.9       10.7          7.2
# 2013              14.1       10.7          7.7
# 2014              14.9       10.9            7
# 2015              15.1       11.5          7.7
# 2016              15.6       10.9          7.6
# 2017              15.4       10.6          7.7

# %%
pivot_percentage_education_df = pivot_percentage_education.copy()

# %%
type(pivot_percentage_education_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Plotting
